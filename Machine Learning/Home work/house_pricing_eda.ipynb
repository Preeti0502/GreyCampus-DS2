# %%
##Importing libraries
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

##Importing data
train=pd.read_csv(r"C:\Users\Dell\Desktop\House_price\train.csv")
test=pd.read_csv(r"C:\Users\Dell\Desktop\House_price\test.csv")

# %%
pd.set_option('display.max_columns', None)
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
##Gives information about the data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#displays all columns
pd.set_option('display.max_columns', None)

##Summarizing data
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
##Check the columns with null values
nan_cols = [i for i in train.columns if train[i].isnull().any()]
nan_cols
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
#Diaplays all rows in output
pd.set_option('display.max_rows', None)

##Check columns with null values
train.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.histplot(train['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
import seaborn as sns
sns.lineplot(x='YrSold',y='SalePrice',data=train)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
##Visualising NA
import seaborn as sns
sns.heatmap(train.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
##Replacing NA's with none as in many columns NA means that facility is unavailable.
#df1 = train.replace({np.nan: None})
#df1

# %%
##Replace none with Nan for missing values
#df1.LotFrontage.fillna(value=np.nan, inplace=True)
#df1.MasVnrArea.fillna(value=np.nan, inplace=True)
#df1.GarageYrBlt.fillna(value=np.nan, inplace=True)
#df1['MasVnrType'].replace('None', np.nan, inplace=True)
#df1['Electrical'].replace('None', np.nan, inplace=True)

# %%
df1=train.drop(["Id","PoolQC", "MiscFeature","Alley","Fence","FireplaceQu"],axis=1)
df1.shape
# Out:
# (1460, 75)

# %%
##Replace Nan with mean in numeric columns
df1['LotFrontage'].fillna((df1['LotFrontage'].mean()), inplace=True)
df1['MasVnrArea'].fillna((df1['MasVnrArea'].mean()), inplace=True)

# %%
##Replace nas  with mode for categorical data and Garage year built
for column in ['MasVnrType', 'Electrical','BsmtQual', 'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType',
               'GarageFinish','GarageQual','GarageCond','GarageYrBlt']:df1[column].fillna(df1[column].mode()[0], inplace=True)

# %%
##Visualising NA's
import seaborn as sns
sns.heatmap(df1.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
##Find correlation between variables
corr=df1.corr()
corr
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.357056 -0.139781     0.032628    -0.059316
# LotFrontage     -0.357056     1.000000  0.306795     0.234196    -0.052820
# LotArea         -0.139781     0.306795  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.234196  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.052820 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.117598  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.082746  0.013788     0.550684     0.073741
# MasVnrArea       0.022895     0.179283  0.103960     0.410238    -0.127788
# BsmtFinSF1      -0.069836     0.215828  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.043340  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.122156 -0.002618     0.308159    -0.136841
# ...

# %%
corr['SalePrice'].sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.475241
# Fireplaces       0.466929
# GarageYrBlt      0.397778
# BsmtFinSF1       0.386420
# LotFrontage      0.334901
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %%
##Find correlated variables 
import matplotlib.pyplot as plt
kot=corr[corr>=0.8]
plt.figure(figsize=(12,10))
sns.heatmap(kot)
# Out:
# <AxesSubplot:>

# %%
categorical_col=df1[['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
                     'Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
                    'MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                    'BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional',
                    'GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','SaleType','SaleCondition']]

# %%
numerical_col=df1.drop(categorical_col,axis=1)
numerical_col
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60    65.000000     8450            7            5       2003
# 1             20    80.000000     9600            6            8       1976
# 2             60    68.000000    11250            7            5       2001
# 3             70    60.000000     9550            7            5       1915
# 4             60    84.000000    14260            8            5       2000
# 5             50    85.000000    14115            5            5       1993
# 6             20    75.000000    10084            8            5       2004
# 7             60    70.049958    10382            7            6       1973
# 8             50    51.000000     6120            7            5       1931
# 9            190    50.000000     7420            5            6       1939
# 10            20    70.000000    11200            5            5       1965
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cat_col=categorical_col.apply(LabelEncoder().fit_transform)

# %%
df2=pd.concat([cat_col,numerical_col],axis=1)
df2.head(10)
# Out:
#    MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0         3       1         3            3          0          4          0
# 1         3       1         3            3          0          2          0
# 2         3       1         0            3          0          4          0
# 3         3       1         0            3          0          0          0
# 4         3       1         0            3          0          2          0
# 5         3       1         0            3          0          4          0
# 6         3       1         3            3          0          4          0
# 7         3       1         0            3          0          0          0
# 8         4       1         3            3          0          4          0
# 9         3       1         3            3          0          0          0
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  RoofStyle  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
scaled_data = pd.DataFrame(Scaler.fit_transform(df2),columns=df2.columns)
scaled_data.head()
# Out:
#    MSZoning    Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0 -0.045532  0.064238  0.750731     0.314667   -0.02618   0.604670  -0.225716
# 1 -0.045532  0.064238  0.750731     0.314667   -0.02618  -0.628316  -0.225716
# 2 -0.045532  0.064238 -1.378933     0.314667   -0.02618   0.604670  -0.225716
# 3 -0.045532  0.064238 -1.378933     0.314667   -0.02618  -1.861302  -0.225716
# 4 -0.045532  0.064238 -1.378933     0.314667   -0.02618  -0.628316  -0.225716
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  RoofStyle  \
# 0     -1.206215   -0.036289    -0.03174 -0.411691    1.026689  -0.491516
# 1      1.954302   -1.188074    -0.03174 -0.411691   -0.543457  -0.491516
# 2     -1.206215   -0.036289    -0.03174 -0.411691    1.026689  -0.491516
# 3     -1.039872   -0.036289    -0.03174 -0.411691    1.026689  -0.491516
# 4      0.457215   -0.036289    -0.03174 -0.411691    1.026689  -0.491516
#
# ...

# %%
##test data
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.shape
# Out:
# (1459, 80)

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1456
# MiscFeature      1408
# Alley            1352
# Fence            1169
# FireplaceQu       730
# LotFrontage       227
# GarageCond         78
# GarageQual         78
# GarageYrBlt        78
# GarageFinish       78
# GarageType         76
# BsmtCond           45
# BsmtQual           44
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinType2       42
# MasVnrType         16
# MasVnrArea         15
# MSZoning            4
# BsmtHalfBath        2
# Utilities           2
# Functional          2
# BsmtFullBath        2
# BsmtFinSF2          1
# BsmtFinSF1          1
# Exterior2nd         1
# BsmtUnfSF           1
# TotalBsmtSF         1
# SaleType            1
# Exterior1st         1
# KitchenQual         1
# GarageArea          1
# GarageCars          1
# HouseStyle          0
# LandSlope           0
# MSSubClass          0
# LotArea             0
# Street              0
# LotShape            0
# LandContour         0
# LotConfig           0
# ...

# %%
df3=test.drop(["Id","PoolQC", "MiscFeature","Alley","Fence","FireplaceQu"],axis=1)
df3.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl        NAmes      Feedr       Norm     1Fam
# 1    AllPub    Corner       Gtl        NAmes       Norm       Norm     1Fam
# 2    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam
# 4    AllPub    Inside       Gtl      StoneBr       Norm       Norm   TwnhsE
#
# ...

# %%
##Replace Nan with mean in numeric columns
for column in ['LotFrontage','MasVnrArea','BsmtHalfBath','BsmtFullBath','BsmtFinSF1','BsmtFinSF2','GarageCars','GarageArea',
    'BsmtUnfSF']:df3[column].fillna(df3[column].mean(),inplace=True)

# %%
##Replace nas  with mode for categorical data and Garage year built
for column in ['MasVnrType','MSZoning','Utilities', 'Electrical','Exterior1st','Exterior2nd','Functional','BsmtQual', 'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType',
               'GarageFinish','GarageQual','GarageCond','GarageYrBlt','KitchenQual','SaleType']:df3[column].fillna(df3[column].mode()[0], inplace=True)

# %%
##Visualising NA's
import seaborn as sns
sns.heatmap(df3.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
test_categorical_col=df3[['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
                     'Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
                    'MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
                    'BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional',
                    'GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','SaleType','SaleCondition']]

# %%
test_numerical_col=df3.drop(categorical_col,axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
test_cat_col=test_categorical_col.apply(LabelEncoder().fit_transform)

# %%
df4=pd.concat([test_cat_col,test_numerical_col],axis=1)
df4.head()
# Out:
#    MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0         2       1         3            3          0          4          0
# 1         3       1         0            3          0          0          0
# 2         3       1         0            3          0          4          0
# 3         3       1         0            3          0          4          0
# 4         3       1         0            1          0          4          0
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  RoofStyle  \
# 0            12           1           2         0           2          1
# 1            12           2           2         0           2          3
# 2             8           2           2         0           4          1
# 3             8           2           2         0           4          1
# 4            22           2           2         4           2          1
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
test_scaled_data = pd.DataFrame(Scaler.fit_transform(df4),columns=df4.columns)
test_scaled_data.head()
# Out:
#    MSZoning   Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0 -1.501777  0.06426  0.742620      0.31870        0.0   0.572445  -0.207992
# 1 -0.039098  0.06426 -1.384637      0.31870        0.0  -1.950811  -0.207992
# 2 -0.039098  0.06426 -1.384637      0.31870        0.0   0.572445  -0.207992
# 3 -0.039098  0.06426 -1.384637      0.31870        0.0   0.572445  -0.207992
# 4 -0.039098  0.06426 -1.384637     -2.53396        0.0   0.572445  -0.207992
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  RoofStyle  \
# 0     -0.105672   -1.193183    0.028691 -0.426625   -0.431830  -0.474315
# 1     -0.105672   -0.056113    0.028691 -0.426625   -0.431830   2.006065
# 2     -0.784114   -0.056113    0.028691 -0.426625    0.920188  -0.474315
# 3     -0.784114   -0.056113    0.028691 -0.426625    0.920188  -0.474315
# 4      1.590431   -0.056113    0.028691  2.866737   -0.431830  -0.474315
#
# ...

# %%
##Splitting the train data
# x:features and y:response
x=scaled_data.drop(["SalePrice"],axis=1)
y=scaled_data["SalePrice"]

# %%
##spliting Training data for traning model and checking score

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=4)

# %%
print("x train dim:", x_train.shape)
print("y train dim:", y_train.shape)
print("x test dim:", x_test.shape)
print("y test dim:", y_test.shape)
# Out:
# x train dim: (1022, 74)
# y train dim: (1022,)
# x test dim: (438, 74)
# y test dim: (438,)

# %%
from sklearn.linear_model import LinearRegression
 
regr = LinearRegression()
Lin_mod=regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
##R2
print(regr.score(x_test, y_test))
# Out:
# 0.8620190885333614
